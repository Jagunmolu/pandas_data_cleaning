# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import re
import statistics

# %%
#reading a csv file into a dataframe
df = pd.read_csv("nigerian_spotify_songs.csv")
print(df.shape)
df.head()
# Out:
# (530, 16)
#                        name                         album  \
# 0                    Sparky            Mandy & The Jungle
# 1                shuga rush  EVERYTHING YOU HEARD IS TRUE
# 2                     LITT!                         LITT!
# 3  Confident / Feeling Cool               Enjoy Your Life
# 4                wanted you                         rare.
#
#                 artist artist_top_genre  release_date  length  popularity  \
# 0        Cruel Santino  alternative r&b          2019  144000          48
# 1  Odunsi (The Engine)          afropop          2020   89488          30
# 2                 AYLØ        indie r&b          2018  207758          40
# 3           Lady Donli     nigerian pop          2019  175135          14
# 4  Odunsi (The Engine)          afropop          2018  152049          25
#
#    danceability  acousticness  energy  instrumentalness  liveness  loudness  \
# 0         0.666        0.8510   0.420          0.534000    0.1100    -6.699
# ...

# %%
#checking the details of numerical variables
df.describe()
# Out:
#        release_date         length  popularity  danceability  acousticness  \
# count    530.000000     530.000000  530.000000    530.000000    530.000000
# mean    2015.390566  222298.169811   17.507547      0.741619      0.265412
# std        3.131688   39696.822259   18.992212      0.117522      0.208342
# min     1998.000000   89488.000000    0.000000      0.255000      0.000665
# 25%     2014.000000  199305.000000    0.000000      0.681000      0.089525
# 50%     2016.000000  218509.000000   13.000000      0.761000      0.220500
# 75%     2017.000000  242098.500000   31.000000      0.829500      0.403000
# max     2020.000000  511738.000000   73.000000      0.966000      0.954000
#
#            energy  instrumentalness    liveness    loudness  speechiness  \
# count  530.000000        530.000000  530.000000  530.000000   530.000000
# mean     0.760623          0.016305    0.147308   -4.953011     0.130748
# ...

# %%
df.describe().columns
# Out:
# Index(['release_date', 'length', 'popularity', 'danceability', 'acousticness',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'time_signature'],
#       dtype='object')

# %%
#checking the unique values in the df
value_counts = dict()
for val in list(df.columns):
    value_counts[val] = df[val].nunique()
print(value_counts)
# Out:
# {'name': 497, 'album': 428, 'artist': 171, 'artist_top_genre': 19, 'release_date': 20, 'length': 518, 'popularity': 66, 'danceability': 304, 'acousticness': 406, 'energy': 329, 'instrumentalness': 294, 'liveness': 362, 'loudness': 504, 'speechiness': 386, 'tempo': 514, 'time_signature': 3}

# %%
df.groupby(by="time_signature").count()["name"]
# Out:
# time_signature
# 3     33
# 4    471
# 5     26
# Name: name, dtype: int64

# %%
df.plot.bar(x=list(df["time_signature"].unique()), y=df.groupby(by="time_signature").count()["name"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.plot.bar(x=list(df["time_signature"].unique()), y=df.groupby(by="time_signature").count()["name"])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:1193, in PlotAccessor.bar(self, x, y, **kwargs)
#    1103 @Appender(
#    1104     """
#    1105     See Also
#    (...)
#    1182     self, x: Hashable | None = None, y: Hashable | None = None, **kwargs
#    1183 ) -> PlotAccessor:
#    1184     """
#    1185     Vertical bar plot.
#    1186
#    (...)
#    1191     other axis represents a measured value.
#    1192     """
# -> 1193     return self(kind="bar", x=x, y=y, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:996, in PlotAccessor.__call__(self, *args, **kwargs)
# ...
