# %%
import numpy as np
import pandas as pd
import re

# %%
well_pollution = pd.read_excel("start_Md_water_services_data.xlsx", sheet_name=0)
water_source = pd.read_excel("start_Md_water_services_data.xlsx", sheet_name=1)
visits = pd.read_excel("start_Md_water_services_data.xlsx", sheet_name=2)
project_progress = pd.read_excel("start_Md_water_services_data.xlsx", sheet_name=4)
vendors = pd.read_excel("start_Md_water_services_data.xlsx", sheet_name=5)
location = pd.read_excel("start_Md_water_services_data.xlsx", sheet_name=6)
infrastructure_cost = pd.read_excel("start_Md_water_services_data.xlsx", sheet_name=7)

# %%
print(project_progress.columns)
project_progress.head()
# Out:
# Index(['project_id', 'source_id', 'town', 'source_type', 'improvement',
#        'source_status', 'date_of_completion', 'assigned_vendor',
#        'date_started', 'cost', 'comments', 'address', 'province'],
#       dtype='object')
#    project_id     source_id            town source_type  \
# 0           1  SoIl32582224          Ilanga       river
# 1           2  KiRu28935224  Rural_Kilimani        well
# 2           3  HaRu19752224   Rural_Hawassa  shared_tap
# 3           4  AkLu01628224          Lusaka        well
# 4           5  KiRu29315224  Rural_Kilimani       river
#
#                 improvement source_status date_of_completion assigned_vendor  \
# 0                Drill well       Backlog                NaT             NaN
# 1  Install UV and RO filter       Backlog                NaT             NaN
# 2     Install 2 taps nearby       Backlog                NaT             NaN
# 3  Install UV and RO filter       Backlog                NaT             NaN
# 4                Drill well       Backlog                NaT             NaN
#
#   date_started  cost  comments  address  province
# 0          NaT   NaN       NaN      NaN       NaN
# 1          NaT   NaN       NaN      NaN       NaN
# 2          NaT   NaN       NaN      NaN       NaN
# 3          NaT   NaN       NaN      NaN       NaN
# 4          NaT   NaN       NaN      NaN       NaN

# %%
project_progress.drop(columns=['comments', 'address', 'province'], inplace=True)
print(project_progress.columns)
project_progress.head()
# Out:
# Index(['project_id', 'source_id', 'town', 'source_type', 'improvement',
#        'source_status', 'date_of_completion', 'assigned_vendor',
#        'date_started', 'cost'],
#       dtype='object')
#    project_id     source_id            town source_type  \
# 0           1  SoIl32582224          Ilanga       river
# 1           2  KiRu28935224  Rural_Kilimani        well
# 2           3  HaRu19752224   Rural_Hawassa  shared_tap
# 3           4  AkLu01628224          Lusaka        well
# 4           5  KiRu29315224  Rural_Kilimani       river
#
#                 improvement source_status date_of_completion assigned_vendor  \
# 0                Drill well       Backlog                NaT             NaN
# 1  Install UV and RO filter       Backlog                NaT             NaN
# 2     Install 2 taps nearby       Backlog                NaT             NaN
# 3  Install UV and RO filter       Backlog                NaT             NaN
# 4                Drill well       Backlog                NaT             NaN
#
#   date_started  cost
# 0          NaT   NaN
# 1          NaT   NaN
# 2          NaT   NaN
# 3          NaT   NaN
# 4          NaT   NaN

# %%
print(well_pollution.columns)
well_pollution.head()
# Out:
# Index(['source_id', 'date', 'description', 'pollutant_ppm', 'biological',
#        'results'],
#       dtype='object')
#       source_id  date  description  pollutant_ppm  biological  \
# 0  KiRu28935224   NaN          NaN            NaN         NaN
# 1  AkLu01628224   NaN          NaN            NaN         NaN
# 2  HaZa21742224   NaN          NaN            NaN         NaN
# 3  HaRu19725224   NaN          NaN            NaN         NaN
# 4  SoRu35703224   NaN          NaN            NaN         NaN
#
#                     results
# 0  Contaminated: Biological
# 1  Contaminated: Biological
# 2    Contaminated: Chemical
# 3                     Clean
# 4  Contaminated: Biological

# %%
well_pollution.drop(columns=['date', 'description', 'pollutant_ppm', 'biological'], inplace=True)
print(well_pollution.columns)
well_pollution.head()
# Out:
# Index(['source_id', 'results'], dtype='object')
#       source_id                   results
# 0  KiRu28935224  Contaminated: Biological
# 1  AkLu01628224  Contaminated: Biological
# 2  HaZa21742224    Contaminated: Chemical
# 3  HaRu19725224                     Clean
# 4  SoRu35703224  Contaminated: Biological

# %%
print(location.columns)
location.head()
# Out:
# Index(['location_id', 'address', 'province_name', 'town_name',
#        'location_type'],
#       dtype='object')
#   location_id  address province_name town_name location_type
# 0   AkHa00000      NaN        Akatsi  Harare-A         Urban
# 1   AkHa00001      NaN        Akatsi  Harare-A         Urban
# 2   AkHa00002      NaN        Akatsi  Harare-A         Urban
# 3   AkHa00003      NaN        Akatsi  Harare-A         Urban
# 4   AkHa00004      NaN        Akatsi  Harare-A         Urban

# %%
location.drop(columns=['address'], inplace=True)
print(location.columns)
location.head()
# Out:
# Index(['location_id', 'province_name', 'town_name', 'location_type'], dtype='object')
#   location_id province_name town_name location_type
# 0   AkHa00000        Akatsi  Harare-A         Urban
# 1   AkHa00001        Akatsi  Harare-A         Urban
# 2   AkHa00002        Akatsi  Harare-A         Urban
# 3   AkHa00003        Akatsi  Harare-A         Urban
# 4   AkHa00004        Akatsi  Harare-A         Urban

# %%
infrastructure_cost.head()
# Out:
#                      improvement  unit_cost_USD
# 0                     Drill well           8500
# 1              Install RO filter           4200
# 2       Install UV and RO filter           3200
# 3  Diagnose local infrastructure            350
# 4          Install 1 taps nearby           2000

# %%
infrastructure_cost["rural_adjusted"] = infrastructure_cost["unit_cost_USD"] * 1.5
infrastructure_cost.head()
# Out:
#                      improvement  unit_cost_USD  rural_adjusted
# 0                     Drill well           8500         12750.0
# 1              Install RO filter           4200          6300.0
# 2       Install UV and RO filter           3200          4800.0
# 3  Diagnose local infrastructure            350           525.0
# 4          Install 1 taps nearby           2000          3000.0

# %%
project_progress = project_progress.merge(infrastructure_cost, how="left")
project_progress.head()
# Out:
#    project_id     source_id            town source_type  \
# 0           1  SoIl32582224          Ilanga       river
# 1           2  KiRu28935224  Rural_Kilimani        well
# 2           3  HaRu19752224   Rural_Hawassa  shared_tap
# 3           4  AkLu01628224          Lusaka        well
# 4           5  KiRu29315224  Rural_Kilimani       river
#
#                 improvement source_status date_of_completion assigned_vendor  \
# 0                Drill well       Backlog                NaT             NaN
# 1  Install UV and RO filter       Backlog                NaT             NaN
# 2     Install 2 taps nearby       Backlog                NaT             NaN
# 3  Install UV and RO filter       Backlog                NaT             NaN
# 4                Drill well       Backlog                NaT             NaN
#
#   date_started  cost  unit_cost_USD  rural_adjusted
# 0          NaT   NaN           8500         12750.0
# 1          NaT   NaN           3200          4800.0
# 2          NaT   NaN           4000          6000.0
# 3          NaT   NaN           3200          4800.0
# 4          NaT   NaN           8500         12750.0

# %%
project_progress["budget"] = project_progress.apply(lambda row: row["rural_adjusted"] if "Rural" in row["town"] else row["unit_cost_USD"], axis=1)
project_progress.head()
# Out:
#    project_id     source_id            town source_type  \
# 0           1  SoIl32582224          Ilanga       river
# 1           2  KiRu28935224  Rural_Kilimani        well
# 2           3  HaRu19752224   Rural_Hawassa  shared_tap
# 3           4  AkLu01628224          Lusaka        well
# 4           5  KiRu29315224  Rural_Kilimani       river
#
#                 improvement source_status date_of_completion assigned_vendor  \
# 0                Drill well       Backlog                NaT             NaN
# 1  Install UV and RO filter       Backlog                NaT             NaN
# 2     Install 2 taps nearby       Backlog                NaT             NaN
# 3  Install UV and RO filter       Backlog                NaT             NaN
# 4                Drill well       Backlog                NaT             NaN
#
#   date_started  cost  unit_cost_USD  rural_adjusted   budget
# 0          NaT   NaN           8500         12750.0   8500.0
# 1          NaT   NaN           3200          4800.0   4800.0
# 2          NaT   NaN           4000          6000.0   6000.0
# 3          NaT   NaN           3200          4800.0   3200.0
# 4          NaT   NaN           8500         12750.0  12750.0

# %%
project_progress.head(12)
# Out:
#     project_id     source_id            town         source_type  \
# 0            1  SoIl32582224          Ilanga               river
# 1            2  KiRu28935224  Rural_Kilimani                well
# 2            3  HaRu19752224   Rural_Hawassa          shared_tap
# 3            4  AkLu01628224          Lusaka                well
# 4            5  KiRu29315224  Rural_Kilimani               river
# 5            6  AkRu05234224    Rural_Akatsi  tap_in_home_broken
# 6            7  HaZa21742224        Zanzibar                well
# 7            8  SoRu35008224    Rural_Sokoto          shared_tap
# 8            9  SoRu35703224    Rural_Sokoto                well
# 9           10  AkHa00070224        Harare-A                well
# 10          11  KiHa23304224        Harare-K               river
# 11          12  KiRu26190224  Rural_Kilimani          shared_tap
#
#                       improvement source_status date_of_completion  \
# 0                      Drill well       Backlog                NaT
# 1        Install UV and RO filter       Backlog                NaT
# 2           Install 2 taps nearby       Backlog                NaT
# 3        Install UV and RO filter       Backlog                NaT
# 4                      Drill well       Backlog                NaT
# 5   Diagnose local infrastructure      Complete         2022-12-31
# 6               Install RO filter      Complete         2023-01-01
# 7           Install 8 taps nearby       Backlog                NaT
# 8        Install UV and RO filter       Backlog                NaT
# 9               Install RO filter      Complete         2023-01-01
# 10                     Drill well       Backlog                NaT
# 11          Install 5 taps nearby       Backlog                NaT
#
#    assigned_vendor date_started     cost  unit_cost_USD  rural_adjusted  \
# 0              NaN          NaT      NaN           8500         12750.0
# 1              NaN          NaT      NaN           3200          4800.0
# 2              NaN          NaT      NaN           4000          6000.0
# 3              NaN          NaT      NaN           3200          4800.0
# 4              NaN          NaT      NaN           8500         12750.0
# 5           BSC425   2022-12-31   395.00            350           525.0
# 6           GRS751   2022-12-31  3924.21           4200          6300.0
# 7              NaN          NaT      NaN          16000         24000.0
# 8              NaN          NaT      NaN           3200          4800.0
# 9           BFT485   2022-12-31  4028.41           4200          6300.0
# 10             NaN          NaT      NaN           8500         12750.0
# 11             NaN          NaT      NaN          10000         15000.0
#
#      budget
# 0    8500.0
# 1    4800.0
# 2    6000.0
# 3    3200.0
# 4   12750.0
# 5     525.0
# 6    4200.0
# 7   24000.0
# 8    4800.0
# 9    4200.0
# 10   8500.0
# 11  15000.0

# %%
project_progress["cost_minus_budget"] = project_progress["cost"] - project_progress["budget"]
project_progress.head()
# Out:
#    project_id     source_id            town source_type  \
# 0           1  SoIl32582224          Ilanga       river
# 1           2  KiRu28935224  Rural_Kilimani        well
# 2           3  HaRu19752224   Rural_Hawassa  shared_tap
# 3           4  AkLu01628224          Lusaka        well
# 4           5  KiRu29315224  Rural_Kilimani       river
#
#                 improvement source_status date_of_completion assigned_vendor  \
# 0                Drill well       Backlog                NaT             NaN
# 1  Install UV and RO filter       Backlog                NaT             NaN
# 2     Install 2 taps nearby       Backlog                NaT             NaN
# 3  Install UV and RO filter       Backlog                NaT             NaN
# 4                Drill well       Backlog                NaT             NaN
#
#   date_started  cost  unit_cost_USD  rural_adjusted   budget  \
# 0          NaT   NaN           8500         12750.0   8500.0
# 1          NaT   NaN           3200          4800.0   4800.0
# 2          NaT   NaN           4000          6000.0   6000.0
# 3          NaT   NaN           3200          4800.0   3200.0
# 4          NaT   NaN           8500         12750.0  12750.0
#
#    cost_minus_budget
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
vendors.head()
# Out:
#   vendor_ID               company_name       owner_name  \
# 0    LAV122      Limpopo Aqua Ventures    Kwame Nkrumah
# 1    MDC828  Makgadikgadi Drilling Co.      Amina Yusuf
# 2    TWS267       Tana Water Solutions    Chike Okonkwo
# 3     OE832        Okavango Earthworks  Fatoumata Bamba
# 4    MBS605     Meru Borehole Services      Tendai Moyo
#
#                    company_type
# 0  Groundwater Extraction Teams
# 1  Groundwater Extraction Teams
# 2  Groundwater Extraction Teams
# 3  Groundwater Extraction Teams
# 4  Groundwater Extraction Teams

# %%
vendors["company_type"].unique()
# Out:
# array(['Groundwater Extraction Teams',
#        'Water Distribution System Installation Teams',
#        'Water Purification System Installation Teams',
#        'Civil Infrastructure Assessment Teams'], dtype=object)
