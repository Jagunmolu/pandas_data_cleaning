# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statistics
import seaborn as sns
import math
import re

# %%
df = pd.read_csv("cleaned.csv")
df.head()
# Out:
#    Unnamed: 0      country code continent     sub-region  year  \
# 0           0  Afghanistan  AFG      Asia  Southern Asia  1991
# 1           1  Afghanistan  AFG      Asia  Southern Asia  1992
# 2           2  Afghanistan  AFG      Asia  Southern Asia  1993
# 3           3  Afghanistan  AFG      Asia  Southern Asia  1994
# 4           4  Afghanistan  AFG      Asia  Southern Asia  1995
#
#    female_unemployment  male_unemployment  population  national_strategy  \
# 0               13.615             10.089  10745168.0                NaN
# 1               13.816             10.258  12057436.0                NaN
# 2               13.712             10.165  14003764.0                NaN
# 3               13.722             10.170  15455560.0                NaN
# 4               14.235             10.610  16418911.0                NaN
#
#    education_expenditure  electricity_access adult_population  \
# 0                    NaN                 NaN              NaN
# ...

# %%
df.drop(columns="Unnamed: 0", inplace=True)

# %%
df.head()
# Out:
#        country code continent     sub-region  year  female_unemployment  \
# 0  Afghanistan  AFG      Asia  Southern Asia  1991               13.615
# 1  Afghanistan  AFG      Asia  Southern Asia  1992               13.816
# 2  Afghanistan  AFG      Asia  Southern Asia  1993               13.712
# 3  Afghanistan  AFG      Asia  Southern Asia  1994               13.722
# 4  Afghanistan  AFG      Asia  Southern Asia  1995               14.235
#
#    male_unemployment  population  national_strategy  education_expenditure  \
# 0             10.089  10745168.0                NaN                    NaN
# 1             10.258  12057436.0                NaN                    NaN
# 2             10.165  14003764.0                NaN                    NaN
# 3             10.170  15455560.0                NaN                    NaN
# 4             10.610  16418911.0                NaN                    NaN
#
#    electricity_access adult_population limited_liability_companies  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5146 entries, 0 to 5145
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   country                      5146 non-null   object
#  1   code                         5146 non-null   object
#  2   continent                    5146 non-null   object
#  3   sub-region                   5146 non-null   object
#  4   year                         5146 non-null   int64
#  5   female_unemployment          5146 non-null   float64
#  6   male_unemployment            5146 non-null   float64
#  7   population                   5146 non-null   float64
#  8   national_strategy            251 non-null    float64
#  9   education_expenditure        3048 non-null   float64
#  10  electricity_access           4421 non-null   float64
#  11  adult_population             1283 non-null   object
# ...

# %%
df1 = df.dropna(subset="national_strategy")
df1.head()
# Out:
#          country code continent                       sub-region  year  \
# 28   Afghanistan  AFG      Asia                    Southern Asia  2019
# 29   Afghanistan  AFG      Asia                    Southern Asia  2020
# 152    Argentina  ARG  Americas  Latin America and the Caribbean  2019
# 153    Argentina  ARG  Americas  Latin America and the Caribbean  2020
# 154    Argentina  ARG  Americas  Latin America and the Caribbean  2021
#
#      female_unemployment  male_unemployment  population  national_strategy  \
# 28                14.065             10.410  37769496.0                1.0
# 29                16.863             10.508  38972236.0                1.0
# 152               10.698              9.187  44745516.0                0.0
# 153               12.375             10.763  45036032.0                0.0
# 154               13.277              9.113  45276788.0                3.0
#
#      education_expenditure  electricity_access adult_population  \
# ...

# %%
df1 = df[df['adult_population'].notna()]
df1.head()
# Out:
#         country code continent     sub-region  year  female_unemployment  \
# 18  Afghanistan  AFG      Asia  Southern Asia  2009               14.440
# 19  Afghanistan  AFG      Asia  Southern Asia  2010               14.487
# 20  Afghanistan  AFG      Asia  Southern Asia  2011               14.140
# 21  Afghanistan  AFG      Asia  Southern Asia  2012               14.453
# 22  Afghanistan  AFG      Asia  Southern Asia  2013               14.248
#
#     male_unemployment  population  national_strategy  education_expenditure  \
# 18             10.728  27385310.0                NaN               17.31000
# 19             10.764  28189672.0                NaN               17.06756
# 20             10.462  29249156.0                NaN               16.04843
# 21             10.728  30466484.0                NaN               14.62000
# 22             10.552  31541216.0                NaN               14.10280
#
# ...

# %%
df1.shape
# Out:
# (1283, 14)

# %%
df.columns
# Out:
# Index(['country', 'code', 'continent', 'sub-region', 'year',
#        'female_unemployment', 'male_unemployment', 'population',
#        'national_strategy', 'education_expenditure', 'electricity_access',
#        'adult_population', 'limited_liability_companies',
#        'business_density_rate'],
#       dtype='object')

# %%
import pandas as pd

data = {'Product': ['Computer','Printer','Monitor','Desk','Phone'],
          'Price': [1200,250,400,700,350]
        }

df = pd.DataFrame(data, columns = ['Product','Price'], index = ['Item_1','Item_2','Item_3','Item_4','Item_5'])

df.reset_index(inplace=True)
df = df.rename(columns = {'index':'Items'})

print(df)

# %%
ax.rename(columns={"index": "country"})["country"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 1
# ...

# %%
ax = df[df['continent'] == "Africa"][['country', 'population', "year"]]\
.groupby("country").mean()
ax = ax.rename(columns = {'index': 'country'})
ax.head()
# .plot.barh(x='country', y='population')
# Out:
#                 population    year
# country
# Algeria       3.430300e+07  2006.0
# Angola        2.139912e+07  2006.0
# Benin         8.665665e+06  2006.0
# Botswana      1.958019e+06  2006.0
# Burkina Faso  1.480571e+07  2006.0

# %%
ax.columns
# Out:
# Index(['population', 'year'], dtype='object')

# %%
corr_matrix = df.corr()

colors_list = ['#FF5733', '#FFC300']
cmap = colors.ListedColormap(colors_list)

# Plot the heatmap with custom colors and annotations
plt.imshow(corr_matrix, cmap=cmap, vmin=0\
		, vmax=1, extent=[0, 5, 0, 5])
for i in range(5):
	for j in range(5):
		plt.annotate(str(round(corr_matrix.values[i][j], 2)),\
					xy=(j+0.25, i+0.7),
					ha='center', va='center', color='white')

# Add colorbar
cbar = plt.colorbar(ticks=[0, 0.5, 1])
cbar.ax.set_yticklabels(['Low', 'Medium', 'High'])

# Set plot title and axis labels
plt.title("Correlation Matrix Of The Dataset")
plt.xlabel("Features")
plt.ylabel("Features")

# Set tick labels
plt.xticks(range(len(corr_matrix.columns)),\
		corr_matrix.columns, rotation=90)
plt.yticks(range(len(corr_matrix.columns)),
		corr_matrix.columns)

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 corr_matrix = df.corr()
#       3 colors_list = ['#FF5733', '#FFC300']
#       4 cmap = colors.ListedColormap(colors_list)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...
